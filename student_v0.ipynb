# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Mindy Jen
# * Student pace: full time
# * Scheduled project review date/time: TBD
# * Instructor name: Abhineet Kulkarni
# * Blog post URL: TBD

# %% [markdown]
# # obtaining data

# %%
# Your code here - remember to use markdown cells for comments as well!
# Import statements go here
import pandas as pd
import numpy as np
import math
import scipy.stats as stats
from scipy.stats import pearsonr
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.metrics import r2_score

from warnings import filterwarnings
filterwarnings('ignore')

import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

kc = pd.read_csv('kc_house_data.csv',index_col=None,encoding='latin1')
kc.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ## retrieve data information

# %%
kc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %% [markdown]
# # scrubbing and cleaning Data

# %% [markdown]
# ## run timestamp data conversion

# %%
def general_datetime_converter(df, col):
    df_clone = df.copy()
    df_clone[col] = pd.to_datetime(df_clone[col])
    return df_clone

kc2 = general_datetime_converter(kc, 'date')
kc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null datetime64[ns]
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: datetime64[ns](1), float64(8), int64(11), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## read missing and symbolic values

# %%
def check_cols(df):
    for col in df.columns:
        print('------------------------------------------------------')
        print(col)
        print(f'unique values: {df[col].nunique(dropna=False)} (\'NaN\' included)')
        print(f'NaN exists? {df[col].isna().any()}')
        if df[col].isna().any():
            print(f'how many \'NaN\' values? {df[col].isna().sum()} ({np.divide(df[col].isna().sum(),df.shape[0])*100:.2f}%)')
        print('------------------------------------------------------')
        print(df[col].value_counts(dropna=False, normalize=True))
        print('------------------------------------------------------')
        print('\n') # Break up the output between columns
        
    return None

check_cols(kc2)
# Out:
# ------------------------------------------------------
# id
# unique values: 21420 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 795000620     0.000139
# 1825069031    0.000093
# 2019200220    0.000093
# 7129304540    0.000093
# 1781500435    0.000093
#                 ...
# 7812801125    0.000046
# 4364700875    0.000046
# 3021059276    0.000046
# 880000205     0.000046
# 1777500160    0.000046
# Name: id, Length: 21420, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# date
# unique values: 372 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 2014-06-23    0.006575
# 2014-06-25    0.006066
# 2014-06-26    0.006066
# 2014-07-08    0.005880
# 2015-04-27    0.005834
#                 ...
# 2014-07-27    0.000046
# 2015-03-08    0.000046
# 2014-11-02    0.000046
# 2015-05-15    0.000046
# 2015-05-24    0.000046
# Name: date, Length: 372, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# price
# unique values: 3622 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 350000.0    0.007964
# 450000.0    0.007964
# 550000.0    0.007362
# 500000.0    0.007038
# 425000.0    0.006945
#               ...
# 870515.0    0.000046
# 336950.0    0.000046
# 386100.0    0.000046
# 176250.0    0.000046
# 884744.0    0.000046
# Name: price, Length: 3622, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# bedrooms
# unique values: 12 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 3     0.454878
# 4     0.318655
# 2     0.127796
# 5     0.074131
# 6     0.012594
# 1     0.009075
# 7     0.001760
# 8     0.000602
# 9     0.000278
# 10    0.000139
# 11    0.000046
# 33    0.000046
# Name: bedrooms, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# bathrooms
# unique values: 29 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 2.50    0.248970
# 1.00    0.178312
# 1.75    0.141131
# 2.25    0.094782
# 2.00    0.089364
# 1.50    0.066907
# 2.75    0.054869
# 3.00    0.034866
# 3.50    0.033847
# 3.25    0.027272
# 3.75    0.007177
# 4.00    0.006297
# 4.50    0.004630
# 4.25    0.003658
# 0.75    0.003287
# 4.75    0.001065
# 5.00    0.000972
# 5.25    0.000602
# 5.50    0.000463
# 1.25    0.000417
# 6.00    0.000278
# 5.75    0.000185
# 0.50    0.000185
# 8.00    0.000093
# 6.25    0.000093
# 6.75    0.000093
# 6.50    0.000093
# 7.50    0.000046
# 7.75    0.000046
# Name: bathrooms, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# sqft_living
# unique values: 1034 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 1300    0.006390
# 1400    0.006251
# 1440    0.006158
# 1660    0.005973
# 1010    0.005973
#           ...
# 4970    0.000046
# 2905    0.000046
# 2793    0.000046
# 4810    0.000046
# 1975    0.000046
# Name: sqft_living, Length: 1034, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# sqft_lot
# unique values: 9776 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 5000      0.016576
# 6000      0.013428
# 4000      0.011622
# 7200      0.010187
# 7500      0.005510
#             ...
# 1448      0.000046
# 38884     0.000046
# 17313     0.000046
# 35752     0.000046
# 315374    0.000046
# Name: sqft_lot, Length: 9776, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# floors
# unique values: 6 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 1.0    0.494189
# 2.0    0.381303
# 1.5    0.088438
# 3.0    0.028291
# 2.5    0.007455
# 3.5    0.000324
# Name: floors, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# waterfront
# unique values: 3 ('NaN' included)
# NaN exists? True
# how many 'NaN' values? 2376 (11.00%)
# ------------------------------------------------------
# 0.0    0.883225
# NaN    0.110015
# 1.0    0.006760
# Name: waterfront, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# view
# unique values: 6 ('NaN' included)
# NaN exists? True
# how many 'NaN' values? 63 (0.29%)
# ------------------------------------------------------
# 0.0    0.899292
# 2.0    0.044312
# 3.0    0.023522
# 1.0    0.015280
# 4.0    0.014678
# NaN    0.002917
# Name: view, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# condition
# unique values: 5 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 3    0.649164
# 4    0.262861
# 5    0.078761
# 2    0.007871
# 1    0.001343
# Name: condition, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# grade
# unique values: 11 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 7     0.415521
# 8     0.280826
# 9     0.121082
# 6     0.094365
# 10    0.052507
# 11    0.018475
# 5     0.011205
# 12    0.004121
# 4     0.001250
# 13    0.000602
# 3     0.000046
# Name: grade, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# sqft_above
# unique values: 942 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 1300    0.009816
# 1010    0.009724
# 1200    0.009538
# 1220    0.008890
# 1140    0.008520
#           ...
# 2601    0.000046
# 440     0.000046
# 2473    0.000046
# 2441    0.000046
# 1975    0.000046
# Name: sqft_above, Length: 942, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# sqft_basement
# unique values: 304 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 0.0       0.593879
# ?         0.021021
# 600.0     0.010048
# 500.0     0.009677
# 700.0     0.009631
#             ...
# 2240.0    0.000046
# 475.0     0.000046
# 3500.0    0.000046
# 2600.0    0.000046
# 518.0     0.000046
# Name: sqft_basement, Length: 304, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# yr_built
# unique values: 116 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 2014    0.025883
# 2006    0.020975
# 2005    0.020836
# 2004    0.020049
# 2003    0.019447
#           ...
# 1933    0.001389
# 1901    0.001343
# 1902    0.001250
# 1935    0.001111
# 1934    0.000972
# Name: yr_built, Length: 116, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# yr_renovated
# unique values: 71 ('NaN' included)
# NaN exists? True
# how many 'NaN' values? 3842 (17.79%)
# ------------------------------------------------------
# 0.0       0.787656
# NaN       0.177895
# 2014.0    0.003380
# 2003.0    0.001435
# 2013.0    0.001435
#             ...
# 1944.0    0.000046
# 1948.0    0.000046
# 1976.0    0.000046
# 1934.0    0.000046
# 1953.0    0.000046
# Name: yr_renovated, Length: 71, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# zipcode
# unique values: 70 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 98103    0.027874
# 98038    0.027272
# 98115    0.026994
# 98052    0.026578
# 98117    0.025605
#            ...
# 98102    0.004815
# 98010    0.004630
# 98024    0.003704
# 98148    0.002639
# 98039    0.002315
# Name: zipcode, Length: 70, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# lat
# unique values: 5033 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 47.6624    0.000787
# 47.5491    0.000787
# 47.5322    0.000787
# 47.6846    0.000787
# 47.6711    0.000741
#              ...
# 47.2785    0.000046
# 47.4162    0.000046
# 47.3870    0.000046
# 47.2313    0.000046
# 47.2715    0.000046
# Name: lat, Length: 5033, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# long
# unique values: 751 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# -122.290    0.005325
# -122.300    0.005140
# -122.362    0.004815
# -122.291    0.004630
# -122.372    0.004584
#               ...
# -121.403    0.000046
# -121.804    0.000046
# -121.726    0.000046
# -121.895    0.000046
# -121.893    0.000046
# Name: long, Length: 751, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# sqft_living15
# unique values: 777 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 1540    0.009122
# 1440    0.009029
# 1560    0.008890
# 1500    0.008334
# 1460    0.007825
#           ...
# 4890    0.000046
# 2873    0.000046
# 952     0.000046
# 3193    0.000046
# 2049    0.000046
# Name: sqft_living15, Length: 777, dtype: float64
# ------------------------------------------------------
#
#
# ------------------------------------------------------
# sqft_lot15
# unique values: 8682 ('NaN' included)
# NaN exists? False
# ------------------------------------------------------
# 5000      0.019771
# 4000      0.016484
# 6000      0.013335
# 7200      0.009724
# 4800      0.006714
#             ...
# 11036     0.000046
# 8989      0.000046
# 871200    0.000046
# 809       0.000046
# 6147      0.000046
# Name: sqft_lot15, Length: 8682, dtype: float64
# ------------------------------------------------------

# %% [markdown]
# ## remove erratic symbols

# %%
# Your code here - Manipulate column names
subs = [(' ','_'),('.',''),("'",""),('®',''),('Â',''),('â\x84¢',''),('+','plus'),('½','half'),('-','_')]

def transform_colname(df):
    df_clone = df.copy()
    cols_rename = []
    for col in df_clone.columns:
        for old, new in subs:
            col = col.replace(old,new)
        cols_rename.append(col)
    df_clone.columns = cols_rename
    return df_clone

# %%
def convert_obj_to_num(df, col):
    df_clone = df.copy()
    if df_clone[col].dtype == 'object':
        df_clone[col] = df_clone[col].replace({'?':np.NaN}).astype('float64')
    return df_clone

kc3 = convert_obj_to_num(kc2, 'sqft_basement')
kc3.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront              float64
# view                    float64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement           float64
# yr_built                  int64
# yr_renovated            float64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %% [markdown]
# ## replace missing values

# %%
def find_null_cols(df):
    df_clone = df.copy()
    print('\'NaN\' found in columns as follows:')
    for col in df_clone.columns:
        if (df_clone[col].isnull().any()) | (df_clone[col].isna().any()):
            print(f'\t{col:30} contains {df_clone[col].isna().sum():10} null values ({df_clone[col].isna().sum()*100/df_clone.shape[0]:5.2f}%) !')
    return None

find_null_cols(kc3)
# Out:
# 'NaN' found in columns as follows:
# 	waterfront                     contains       2376 null values (11.00%) !
# 	view                           contains         63 null values ( 0.29%) !
# 	sqft_basement                  contains        454 null values ( 2.10%) !
# 	yr_renovated                   contains       3842 null values (17.79%) !

# %% [markdown]
# ### continuous features

# %%
def fill_null_cols(df, col, nullified=False):
    df_clone = df.copy()
    if nullified:
        df_clone[col] = df_clone[col].fillna(0)
    else:
        try:
            median = df_clone[col].median()
            mean = df_clone[col].mean()
            print(f'{col}: median {median:.3f}, mean {mean:.3f}')
            if median > 0:
                df_clone[col] = df_clone[col].fillna(median)
            else:
                df_clone[col] = df_clone[col].fillna(mean)
        except:
            print('N/A')
    return df_clone

# %%
kc4 = fill_null_cols(kc3, 'sqft_basement', nullified=False)
kc4.sqft_basement.isna().any()
# Out:
# sqft_basement: median 0.000, mean 291.852
# False

# %%
kc5 = fill_null_cols(kc4, 'yr_renovated', nullified=True)
print(kc5.yr_renovated.isna().any())
kc5.yr_renovated.unique()
# Out:
# False
# array([   0., 1991., 2002., 2010., 1992., 2013., 1994., 1978., 2005.,
#        2003., 1984., 1954., 2014., 2011., 1983., 1945., 1990., 1988.,
#        1977., 1981., 1995., 2000., 1999., 1998., 1970., 1989., 2004.,
#        1986., 2007., 1987., 2006., 1985., 2001., 1980., 1971., 1979.,
#        1997., 1950., 1969., 1948., 2009., 2015., 1974., 2008., 1968.,
#        2012., 1963., 1951., 1962., 1953., 1993., 1996., 1955., 1982.,
#        1956., 1940., 1976., 1946., 1975., 1964., 1973., 1957., 1959.,
#        1960., 1967., 1965., 1934., 1972., 1944., 1958.])

# %% [markdown]
# ### discrete, categorical features

# %%
def replace_null_cols(df, col, obj=False):
    df_clone = df.copy()
    if obj:
        df_clone[col] = df_clone[col].fillna('unknown')
    else:
        #df_clone[col] = df_clone[col].fillna(-1)
        # Thomas T. 
        df_clone[col] = df_clone[col].fillna(0)
    return df_clone

# %%
kc6 = replace_null_cols(kc5, 'waterfront', obj=False)
kc6.waterfront.isna().any()
# Out:
# False

# %%
kc7 = replace_null_cols(kc6, 'view', obj=False)
kc7.view.isna().any()
# Out:
# False

# %%
def transform_col_to_binary(df, col):
    df_clone = df.copy()
    df_clone[col+'_korg'] = df_clone[col]
    for idx in range(df_clone.shape[0]):
        if df_clone.loc[idx,col] > 0:
            df_clone.loc[idx,col] = 1
    return df_clone

# %%
kc7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null datetime64[ns]
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null float64
# view             21597 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null float64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: datetime64[ns](1), float64(9), int64(11)
# memory usage: 3.5 MB

# %%
kc8 = transform_col_to_binary(kc7, 'yr_renovated')
print('any NaN?',kc8.yr_renovated.isna().sum())
print(kc8.yr_renovated.nunique())
print('after:',kc8.yr_renovated.unique())
print('before:',kc8.yr_renovated_korg.unique())
# Out:
# any NaN? 0
# 2
# after: [0. 1.]
# before: [   0. 1991. 2002. 2010. 1992. 2013. 1994. 1978. 2005. 2003. 1984. 1954.
#  2014. 2011. 1983. 1945. 1990. 1988. 1977. 1981. 1995. 2000. 1999. 1998.
#  1970. 1989. 2004. 1986. 2007. 1987. 2006. 1985. 2001. 1980. 1971. 1979.
#  1997. 1950. 1969. 1948. 2009. 2015. 1974. 2008. 1968. 2012. 1963. 1951.
#  1962. 1953. 1993. 1996. 1955. 1982. 1956. 1940. 1976. 1946. 1975. 1964.
#  1973. 1957. 1959. 1960. 1967. 1965. 1934. 1972. 1944. 1958.]

# %% [markdown]
# ## remove duplications

# %%
def check_remove_duplicated_data(df):
    df_clone = df.copy()
    #df_clone['is_duplicated'] = df_clone.duplicated(subset=None, keep='first')
    do_drop = '0'
    for col in df_clone.columns:
        print(f'{col} contains duplications?')
        if df_clone[col].duplicated().value_counts(normalize=True, sort=False)[0] == 1:
            print('Nope!')
        else:
            print(f'Yes, how much? {df_clone[col].duplicated().value_counts(normalize=True, sort=False)[1]}')
            do_drop = input('drop? enter 1 (\'True\') or 0 (\'False\')')
            if do_drop == '1':
                df_clone[col+'_kdup'] = df_clone[col]
                #df_clone[col] = df_clone[col].drop_duplicates(keep='first') 
                # Thomas T.
                df_clone[col] = df_clone[col].drop_duplicates(keep='last')
                print(f' duplications in {col} dropped ... ')
            else:
                print(f' skip {col} ... ')
        print('---------------------------------------------------------------------------')
    return df_clone

# %%
kc9 = check_remove_duplicated_data(kc8)
kc9.columns
# Out:
# id contains duplications?
# Yes, how much? 0.008195582719822198
# drop? enter 1 ('True') or 0 ('False')1
#  duplications in id dropped ...
# ---------------------------------------------------------------------------
# date contains duplications?
# Yes, how much? 0.9827753854702042
# drop? enter 1 ('True') or 0 ('False')0
#  skip date ...
# ---------------------------------------------------------------------------
# price contains duplications?
# Yes, how much? 0.832291521970644
# drop? enter 1 ('True') or 0 ('False')0
#  skip price ...
# ---------------------------------------------------------------------------
# bedrooms contains duplications?
# Yes, how much? 0.9994443672732324
# drop? enter 1 ('True') or 0 ('False')0
#  skip bedrooms ...
# ---------------------------------------------------------------------------
# bathrooms contains duplications?
# Yes, how much? 0.9986572209103116
# drop? enter 1 ('True') or 0 ('False')0
#  skip bathrooms ...
# ---------------------------------------------------------------------------
# sqft_living contains duplications?
# Yes, how much? 0.9521229800435246
# drop? enter 1 ('True') or 0 ('False')0
#  skip sqft_living ...
# ---------------------------------------------------------------------------
# sqft_lot contains duplications?
# Yes, how much? 0.5473445385933231
# drop? enter 1 ('True') or 0 ('False')0
#  skip sqft_lot ...
# ---------------------------------------------------------------------------
# floors contains duplications?
# Yes, how much? 0.9997221836366162
# drop? enter 1 ('True') or 0 ('False')0
#  skip floors ...
# ---------------------------------------------------------------------------
# waterfront contains duplications?
# Yes, how much? 0.9999073945455388
# drop? enter 1 ('True') or 0 ('False')0
#  skip waterfront ...
# ---------------------------------------------------------------------------
# view contains duplications?
# Yes, how much? 0.9997684863638469
# drop? enter 1 ('True') or 0 ('False')0
#  skip view ...
# ---------------------------------------------------------------------------
# condition contains duplications?
# Yes, how much? 0.9997684863638469
# drop? enter 1 ('True') or 0 ('False')0
#  skip condition ...
# ---------------------------------------------------------------------------
# grade contains duplications?
# Yes, how much? 0.999490670000463
# drop? enter 1 ('True') or 0 ('False')0
#  skip grade ...
# ---------------------------------------------------------------------------
# sqft_above contains duplications?
# Yes, how much? 0.9563828309487429
# drop? enter 1 ('True') or 0 ('False')0
#  skip sqft_above ...
# ---------------------------------------------------------------------------
# sqft_basement contains duplications?
# Yes, how much? 0.9859239709218873
# drop? enter 1 ('True') or 0 ('False')0
#  skip sqft_basement ...
# ---------------------------------------------------------------------------
# yr_built contains duplications?
# Yes, how much? 0.9946288836412465
# drop? enter 1 ('True') or 0 ('False')0
#  skip yr_built ...
# ---------------------------------------------------------------------------
# yr_renovated contains duplications?
# Yes, how much? 0.9999073945455388
# drop? enter 1 ('True') or 0 ('False')0
#  skip yr_renovated ...
# ---------------------------------------------------------------------------
# zipcode contains duplications?
# Yes, how much? 0.9967588090938556
# drop? enter 1 ('True') or 0 ('False')0
#  skip zipcode ...
# ---------------------------------------------------------------------------
# lat contains duplications?
# Yes, how much? 0.7669583738482196
# drop? enter 1 ('True') or 0 ('False')0
#  skip lat ...
# ---------------------------------------------------------------------------
# long contains duplications?
# Yes, how much? 0.965226651849794
# drop? enter 1 ('True') or 0 ('False')0
#  skip long ...
# ---------------------------------------------------------------------------
# sqft_living15 contains duplications?
# Yes, how much? 0.9640227809417975
# drop? enter 1 ('True') or 0 ('False')0
#  skip sqft_living15 ...
# ---------------------------------------------------------------------------
# sqft_lot15 contains duplications?
# Yes, how much? 0.5979997221836366
# drop? enter 1 ('True') or 0 ('False')0
#  skip sqft_lot15 ...
# ---------------------------------------------------------------------------
# yr_renovated_korg contains duplications?
# Yes, how much? 0.9967588090938556
# drop? enter 1 ('True') or 0 ('False')0
#  skip yr_renovated_korg ...
# ---------------------------------------------------------------------------
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'yr_renovated_korg',
#        'id_kdup'],
#       dtype='object')

# %% [markdown]
# ## remove extreme outliers

# %%
def check_outliers(df):
    df_clone = df.copy()
    cuts = []
    do_work = '0'
    do_cut = '0'
    read_cut = '0'
    
    for col in df_clone.columns:
        print('\n')
        print('***************************************************************************')
        print(f'{col} (data type: {df_clone[col].dtype}):')
        do_work = input('wanna continue? enter 1 (\'True\') or 0 (\'False\')')
        if do_work == '1':    
            print ('----------------------------------------------------------------------')
            print(df_clone[col].value_counts(dropna=False,normalize=True))
            print ('----------------------------------------------------------------------')
            for i in range(80,100):
                q = i/100
                print(f'\t{q} percentile: {df_clone[col].quantile(q=q)}')
            print('-----------------------------------------------------------------------')
            do_cut = input('make cut? enter 1 (\'True\') or 0 (\'False\')')
            if do_cut == '1':
                print(f'\tcut on {col} applied ... ')
                try:
                    print(f'\tcut value: {0.98*df_clone[col].quantile(q=0.99)}')
                    orig_tot = df_clone.shape[0]
                    df_clone = df_clone[df_clone[col]<0.98*df_clone[col].quantile(q=0.99)]
                    print(f'\tPercent removed: {(orig_tot-df_clone.shape[0])/orig_tot}')
                    cuts.append([col,round(0.98*df_clone[col].quantile(q=0.99),3),(orig_tot-df_clone.shape[0])/orig_tot])
                except Exception as e:
                    print('\t\t>>> Sorry! ',e)
            else:
                print(f'\tskip {col} ... ')
                read_cut = input('\tbut... wanna read cut? enter 1 (\'True\') or 0 (\'False\')')
                if read_cut == '1':
                    try:
                        print(f'\tcut value: {0.98*df_clone[col].quantile(q=0.99)}')
                        orig_tot = df_clone.shape[0]
                        df_clone = df_clone[df_clone[col]<0.98*df_clone[col].quantile(q=0.99)]
                        print(f'\tPercent removed: {(orig_tot-df_clone.shape[0])/orig_tot}')
                        cuts.append([col,round(0.98*df_clone[col].quantile(q=0.99),3),(orig_tot-df_clone.shape[0])/orig_tot])
                    except Exception as e:
                        print('\t\t>>> Sorry! ',e)
                    df_clone = df.copy()
                else:
                    cuts.append([col,0.,0.])
        else:
            cuts.append([col,0.,0.])
            continue
        input("Press Enter to continue...")
    return cuts, df_clone

# %%
results, kc10 = check_outliers(kc9)
print(kc10.columns)
results
# Out:
# ***************************************************************************
# id (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# date (data type: datetime64[ns]):
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# price (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 350000.0    0.007964
# 450000.0    0.007964
# 550000.0    0.007362
# 500000.0    0.007038
# 425000.0    0.006945
#               ...
# 870515.0    0.000046
# 336950.0    0.000046
# 386100.0    0.000046
# 176250.0    0.000046
# 884744.0    0.000046
# Name: price, Length: 3622, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 700435.9999999998
# 	0.81 percentile: 718000.0
# 	0.82 percentile: 730000.72
# 	0.83 percentile: 749950.0
# 	0.84 percentile: 760003.2
# 	0.85 percentile: 779721.9999999991
# 	0.86 percentile: 799000.0
# 	0.87 percentile: 815000.0
# 	0.88 percentile: 836739.9999999998
# 	0.89 percentile: 859967.6
# 	0.9 percentile: 887000.0
# 	0.91 percentile: 919993.6
# 	0.92 percentile: 950000.0
# 	0.93 percentile: 997964.0000000002
# 	0.94 percentile: 1060000.0
# 	0.95 percentile: 1160000.0
# 	0.96 percentile: 1260000.0
# 	0.97 percentile: 1390000.0
# 	0.98 percentile: 1600000.0
# 	0.99 percentile: 1970000.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip price ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 1930600.0
# 	Percent removed: 0.010742232717507062
# Press Enter to continue...
#
#
# ***************************************************************************
# bedrooms (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 3     0.454878
# 4     0.318655
# 2     0.127796
# 5     0.074131
# 6     0.012594
# 1     0.009075
# 7     0.001760
# 8     0.000602
# 9     0.000278
# 10    0.000139
# 11    0.000046
# 33    0.000046
# Name: bedrooms, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 4.0
# 	0.81 percentile: 4.0
# 	0.82 percentile: 4.0
# 	0.83 percentile: 4.0
# 	0.84 percentile: 4.0
# 	0.85 percentile: 4.0
# 	0.86 percentile: 4.0
# 	0.87 percentile: 4.0
# 	0.88 percentile: 4.0
# 	0.89 percentile: 4.0
# 	0.9 percentile: 4.0
# 	0.91 percentile: 4.0
# 	0.92 percentile: 5.0
# 	0.93 percentile: 5.0
# 	0.94 percentile: 5.0
# 	0.95 percentile: 5.0
# 	0.96 percentile: 5.0
# 	0.97 percentile: 5.0
# 	0.98 percentile: 5.0
# 	0.99 percentile: 6.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip bedrooms ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 5.88
# 	Percent removed: 0.015465110895031718
# Press Enter to continue...
#
#
# ***************************************************************************
# bathrooms (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 2.50    0.248970
# 1.00    0.178312
# 1.75    0.141131
# 2.25    0.094782
# 2.00    0.089364
# 1.50    0.066907
# 2.75    0.054869
# 3.00    0.034866
# 3.50    0.033847
# 3.25    0.027272
# 3.75    0.007177
# 4.00    0.006297
# 4.50    0.004630
# 4.25    0.003658
# 0.75    0.003287
# 4.75    0.001065
# 5.00    0.000972
# 5.25    0.000602
# 5.50    0.000463
# 1.25    0.000417
# 6.00    0.000278
# 5.75    0.000185
# 0.50    0.000185
# 8.00    0.000093
# 6.25    0.000093
# 6.75    0.000093
# 6.50    0.000093
# 7.50    0.000046
# 7.75    0.000046
# Name: bathrooms, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 2.5
# 	0.81 percentile: 2.5
# 	0.82 percentile: 2.5
# 	0.83 percentile: 2.75
# 	0.84 percentile: 2.75
# 	0.85 percentile: 2.75
# 	0.86 percentile: 2.75
# 	0.87 percentile: 2.75
# 	0.88 percentile: 3.0
# 	0.89 percentile: 3.0
# 	0.9 percentile: 3.0
# 	0.91 percentile: 3.0
# 	0.92 percentile: 3.25
# 	0.93 percentile: 3.25
# 	0.94 percentile: 3.25
# 	0.95 percentile: 3.5
# 	0.96 percentile: 3.5
# 	0.97 percentile: 3.5
# 	0.98 percentile: 3.75
# 	0.99 percentile: 4.25
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip bathrooms ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 4.165
# 	Percent removed: 0.012316525443348613
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_living (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 1300    0.006390
# 1400    0.006251
# 1440    0.006158
# 1660    0.005973
# 1010    0.005973
#           ...
# 4970    0.000046
# 2905    0.000046
# 2793    0.000046
# 4810    0.000046
# 1975    0.000046
# Name: sqft_living, Length: 1034, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 2730.0
# 	0.81 percentile: 2770.0
# 	0.82 percentile: 2820.0
# 	0.83 percentile: 2860.0
# 	0.84 percentile: 2910.0
# 	0.85 percentile: 2970.0
# 	0.86 percentile: 3020.0
# 	0.87 percentile: 3070.0
# 	0.88 percentile: 3131.4399999999987
# 	0.89 percentile: 3190.0
# 	0.9 percentile: 3254.0000000000146
# 	0.91 percentile: 3340.0
# 	0.92 percentile: 3420.0
# 	0.93 percentile: 3510.0
# 	0.94 percentile: 3630.0
# 	0.95 percentile: 3760.0
# 	0.96 percentile: 3920.0
# 	0.97 percentile: 4140.0
# 	0.98 percentile: 4410.0
# 	0.99 percentile: 4980.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip sqft_living ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 4880.4
# 	Percent removed: 0.010927443626429596
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_lot (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 5000      0.016576
# 6000      0.013428
# 4000      0.011622
# 7200      0.010187
# 7500      0.005510
#             ...
# 1448      0.000046
# 38884     0.000046
# 17313     0.000046
# 35752     0.000046
# 315374    0.000046
# Name: sqft_lot, Length: 9776, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 12182.399999999998
# 	0.81 percentile: 12558.0
# 	0.82 percentile: 13055.439999999995
# 	0.83 percentile: 13503.68
# 	0.84 percentile: 14197.0
# 	0.85 percentile: 15000.0
# 	0.86 percentile: 15716.040000000012
# 	0.87 percentile: 16646.640000000003
# 	0.88 percentile: 18000.0
# 	0.89 percentile: 19550.0
# 	0.9 percentile: 21371.600000000006
# 	0.91 percentile: 24149.360000000015
# 	0.92 percentile: 28505.119999999995
# 	0.93 percentile: 34848.0
# 	0.94 percentile: 37643.19999999999
# 	0.95 percentile: 43307.200000000026
# 	0.96 percentile: 50655.28
# 	0.97 percentile: 67381.7199999999
# 	0.98 percentile: 107157.0
# 	0.99 percentile: 213008.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip sqft_lot ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 208747.84
# 	Percent removed: 0.01097374635366023
# Press Enter to continue...
#
#
# ***************************************************************************
# floors (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 1.0    0.494189
# 2.0    0.381303
# 1.5    0.088438
# 3.0    0.028291
# 2.5    0.007455
# 3.5    0.000324
# Name: floors, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 2.0
# 	0.81 percentile: 2.0
# 	0.82 percentile: 2.0
# 	0.83 percentile: 2.0
# 	0.84 percentile: 2.0
# 	0.85 percentile: 2.0
# 	0.86 percentile: 2.0
# 	0.87 percentile: 2.0
# 	0.88 percentile: 2.0
# 	0.89 percentile: 2.0
# 	0.9 percentile: 2.0
# 	0.91 percentile: 2.0
# 	0.92 percentile: 2.0
# 	0.93 percentile: 2.0
# 	0.94 percentile: 2.0
# 	0.95 percentile: 2.0
# 	0.96 percentile: 2.0
# 	0.97 percentile: 2.5
# 	0.98 percentile: 3.0
# 	0.99 percentile: 3.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip floors ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 2.94
# 	Percent removed: 0.02861508542853174
# Press Enter to continue...
#
#
# ***************************************************************************
# waterfront (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.0    0.99324
# 1.0    0.00676
# Name: waterfront, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 0.0
# 	0.81 percentile: 0.0
# 	0.82 percentile: 0.0
# 	0.83 percentile: 0.0
# 	0.84 percentile: 0.0
# 	0.85 percentile: 0.0
# 	0.86 percentile: 0.0
# 	0.87 percentile: 0.0
# 	0.88 percentile: 0.0
# 	0.89 percentile: 0.0
# 	0.9 percentile: 0.0
# 	0.91 percentile: 0.0
# 	0.92 percentile: 0.0
# 	0.93 percentile: 0.0
# 	0.94 percentile: 0.0
# 	0.95 percentile: 0.0
# 	0.96 percentile: 0.0
# 	0.97 percentile: 0.0
# 	0.98 percentile: 0.0
# 	0.99 percentile: 0.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip waterfront ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 0.0
# 	Percent removed: 1.0
# Press Enter to continue...
#
#
# ***************************************************************************
# view (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.0    0.902209
# 2.0    0.044312
# 3.0    0.023522
# 1.0    0.015280
# 4.0    0.014678
# Name: view, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 0.0
# 	0.81 percentile: 0.0
# 	0.82 percentile: 0.0
# 	0.83 percentile: 0.0
# 	0.84 percentile: 0.0
# 	0.85 percentile: 0.0
# 	0.86 percentile: 0.0
# 	0.87 percentile: 0.0
# 	0.88 percentile: 0.0
# 	0.89 percentile: 0.0
# 	0.9 percentile: 0.0
# 	0.91 percentile: 1.0
# 	0.92 percentile: 2.0
# 	0.93 percentile: 2.0
# 	0.94 percentile: 2.0
# 	0.95 percentile: 2.0
# 	0.96 percentile: 2.0
# 	0.97 percentile: 3.0
# 	0.98 percentile: 3.0
# 	0.99 percentile: 4.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip view ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 3.92
# 	Percent removed: 0.014677964532110942
# Press Enter to continue...
#
#
# ***************************************************************************
# condition (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 3    0.649164
# 4    0.262861
# 5    0.078761
# 2    0.007871
# 1    0.001343
# Name: condition, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 4.0
# 	0.81 percentile: 4.0
# 	0.82 percentile: 4.0
# 	0.83 percentile: 4.0
# 	0.84 percentile: 4.0
# 	0.85 percentile: 4.0
# 	0.86 percentile: 4.0
# 	0.87 percentile: 4.0
# 	0.88 percentile: 4.0
# 	0.89 percentile: 4.0
# 	0.9 percentile: 4.0
# 	0.91 percentile: 4.0
# 	0.92 percentile: 4.0
# 	0.93 percentile: 5.0
# 	0.94 percentile: 5.0
# 	0.95 percentile: 5.0
# 	0.96 percentile: 5.0
# 	0.97 percentile: 5.0
# 	0.98 percentile: 5.0
# 	0.99 percentile: 5.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip condition ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 4.9
# 	Percent removed: 0.07876093901930824
# Press Enter to continue...
#
#
# ***************************************************************************
# grade (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 7     0.415521
# 8     0.280826
# 9     0.121082
# 6     0.094365
# 10    0.052507
# 11    0.018475
# 5     0.011205
# 12    0.004121
# 4     0.001250
# 13    0.000602
# 3     0.000046
# Name: grade, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 8.0
# 	0.81 percentile: 9.0
# 	0.82 percentile: 9.0
# 	0.83 percentile: 9.0
# 	0.84 percentile: 9.0
# 	0.85 percentile: 9.0
# 	0.86 percentile: 9.0
# 	0.87 percentile: 9.0
# 	0.88 percentile: 9.0
# 	0.89 percentile: 9.0
# 	0.9 percentile: 9.0
# 	0.91 percentile: 9.0
# 	0.92 percentile: 9.0
# 	0.93 percentile: 10.0
# 	0.94 percentile: 10.0
# 	0.95 percentile: 10.0
# 	0.96 percentile: 10.0
# 	0.97 percentile: 10.0
# 	0.98 percentile: 11.0
# 	0.99 percentile: 11.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip grade ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 10.78
# 	Percent removed: 0.023197666342547576
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_above (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 1300    0.009816
# 1010    0.009724
# 1200    0.009538
# 1220    0.008890
# 1140    0.008520
#           ...
# 2601    0.000046
# 440     0.000046
# 2473    0.000046
# 2441    0.000046
# 1975    0.000046
# Name: sqft_above, Length: 942, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 2410.0
# 	0.81 percentile: 2450.0
# 	0.82 percentile: 2500.0
# 	0.83 percentile: 2550.0
# 	0.84 percentile: 2590.0
# 	0.85 percentile: 2640.0
# 	0.86 percentile: 2690.0
# 	0.87 percentile: 2750.0
# 	0.88 percentile: 2801.4399999999987
# 	0.89 percentile: 2870.0
# 	0.9 percentile: 2950.0
# 	0.91 percentile: 3020.0
# 	0.92 percentile: 3100.0
# 	0.93 percentile: 3190.0
# 	0.94 percentile: 3270.0
# 	0.95 percentile: 3400.0
# 	0.96 percentile: 3520.0
# 	0.97 percentile: 3700.0
# 	0.98 percentile: 3970.0
# 	0.99 percentile: 4370.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip sqft_above ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 4282.6
# 	Percent removed: 0.011344168171505301
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_basement (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.000000       0.593879
# 291.851724     0.021021
# 600.000000     0.010048
# 500.000000     0.009677
# 700.000000     0.009631
#                  ...
# 588.000000     0.000046
# 1920.000000    0.000046
# 2390.000000    0.000046
# 1245.000000    0.000046
# 1135.000000    0.000046
# Name: sqft_basement, Length: 304, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 690.0
# 	0.81 percentile: 700.0
# 	0.82 percentile: 730.0
# 	0.83 percentile: 760.0
# 	0.84 percentile: 790.0
# 	0.85 percentile: 800.0
# 	0.86 percentile: 840.0
# 	0.87 percentile: 870.0
# 	0.88 percentile: 900.0
# 	0.89 percentile: 920.0
# 	0.9 percentile: 960.0
# 	0.91 percentile: 1000.0
# 	0.92 percentile: 1020.0
# 	0.93 percentile: 1062.8000000000247
# 	0.94 percentile: 1110.0
# 	0.95 percentile: 1180.0
# 	0.96 percentile: 1250.0
# 	0.97 percentile: 1330.0
# 	0.98 percentile: 1440.0
# 	0.99 percentile: 1660.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip sqft_basement ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 1626.8
# 	Percent removed: 0.010881140899198963
# Press Enter to continue...
#
#
# ***************************************************************************
# yr_built (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 2014    0.025883
# 2006    0.020975
# 2005    0.020836
# 2004    0.020049
# 2003    0.019447
#           ...
# 1933    0.001389
# 1901    0.001343
# 1902    0.001250
# 1935    0.001111
# 1934    0.000972
# Name: yr_built, Length: 116, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 2001.0
# 	0.81 percentile: 2002.0
# 	0.82 percentile: 2003.0
# 	0.83 percentile: 2003.0
# 	0.84 percentile: 2004.0
# 	0.85 percentile: 2004.0
# 	0.86 percentile: 2005.0
# 	0.87 percentile: 2005.0
# 	0.88 percentile: 2006.0
# 	0.89 percentile: 2006.0
# 	0.9 percentile: 2007.0
# 	0.91 percentile: 2007.0
# 	0.92 percentile: 2008.0
# 	0.93 percentile: 2008.0
# 	0.94 percentile: 2009.0
# 	0.95 percentile: 2011.0
# 	0.96 percentile: 2012.0
# 	0.97 percentile: 2013.0
# 	0.98 percentile: 2014.0
# 	0.99 percentile: 2014.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip yr_built ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 1973.72
# 	Percent removed: 0.5102560540815854
# Press Enter to continue...
#
#
# ***************************************************************************
# yr_renovated (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# zipcode (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# lat (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# long (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# sqft_living15 (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 1540    0.009122
# 1440    0.009029
# 1560    0.008890
# 1500    0.008334
# 1460    0.007825
#           ...
# 4890    0.000046
# 2873    0.000046
# 952     0.000046
# 3193    0.000046
# 2049    0.000046
# Name: sqft_living15, Length: 777, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 2510.0
# 	0.81 percentile: 2550.0
# 	0.82 percentile: 2580.0
# 	0.83 percentile: 2610.0
# 	0.84 percentile: 2650.0
# 	0.85 percentile: 2690.0
# 	0.86 percentile: 2730.0
# 	0.87 percentile: 2780.0
# 	0.88 percentile: 2820.0
# 	0.89 percentile: 2870.0
# 	0.9 percentile: 2930.0
# 	0.91 percentile: 2980.0
# 	0.92 percentile: 3040.0
# 	0.93 percentile: 3130.0
# 	0.94 percentile: 3200.0
# 	0.95 percentile: 3300.0
# 	0.96 percentile: 3420.0
# 	0.97 percentile: 3560.0
# 	0.98 percentile: 3760.799999999981
# 	0.99 percentile: 4080.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip sqft_living15 ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 3998.4
# 	Percent removed: 0.01180719544381164
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_lot15 (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 5000      0.019771
# 4000      0.016484
# 6000      0.013335
# 7200      0.009724
# 4800      0.006714
#             ...
# 11036     0.000046
# 8989      0.000046
# 871200    0.000046
# 809       0.000046
# 6147      0.000046
# Name: sqft_lot15, Length: 8682, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 11088.8
# 	0.81 percentile: 11399.520000000004
# 	0.82 percentile: 11720.719999999998
# 	0.83 percentile: 12054.0
# 	0.84 percentile: 12456.119999999995
# 	0.85 percentile: 13000.0
# 	0.86 percentile: 13640.560000000001
# 	0.87 percentile: 14405.52
# 	0.88 percentile: 15177.0
# 	0.89 percentile: 16196.07999999999
# 	0.9 percentile: 17822.000000000007
# 	0.91 percentile: 19871.600000000006
# 	0.92 percentile: 22356.32
# 	0.93 percentile: 27600.0
# 	0.94 percentile: 35021.0
# 	0.95 percentile: 37045.20000000001
# 	0.96 percentile: 42627.87999999999
# 	0.97 percentile: 51400.0
# 	0.98 percentile: 80152.2399999999
# 	0.99 percentile: 157687.0
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip sqft_lot15 ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 154533.26
# 	Percent removed: 0.010232902717970088
# Press Enter to continue...
#
#
# ***************************************************************************
# yr_renovated_korg (data type: float64):
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.0       0.965551
# 2014.0    0.003380
# 2003.0    0.001435
# 2013.0    0.001435
# 2007.0    0.001389
#             ...
# 1946.0    0.000046
# 1959.0    0.000046
# 1971.0    0.000046
# 1951.0    0.000046
# 1954.0    0.000046
# Name: yr_renovated_korg, Length: 70, dtype: float64
# ----------------------------------------------------------------------
# 	0.8 percentile: 0.0
# 	0.81 percentile: 0.0
# 	0.82 percentile: 0.0
# 	0.83 percentile: 0.0
# 	0.84 percentile: 0.0
# 	0.85 percentile: 0.0
# 	0.86 percentile: 0.0
# 	0.87 percentile: 0.0
# 	0.88 percentile: 0.0
# 	0.89 percentile: 0.0
# 	0.9 percentile: 0.0
# 	0.91 percentile: 0.0
# 	0.92 percentile: 0.0
# 	0.93 percentile: 0.0
# 	0.94 percentile: 0.0
# 	0.95 percentile: 0.0
# 	0.96 percentile: 0.0
# 	0.97 percentile: 1979.0
# 	0.98 percentile: 1996.0
# 	0.99 percentile: 2006.0400000000009
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip yr_renovated_korg ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')1
# 	cut value: 1965.9192000000007
# 	Percent removed: 0.032458211788674356
# Press Enter to continue...
#
#
# ***************************************************************************
# id_kdup (data type: int64):
# wanna continue? enter 1 ('True') or 0 ('False')0
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'yr_renovated_korg',
#        'id_kdup'],
#       dtype='object')
# [['id', 0.0, 0.0],
#  ['date', 0.0, 0.0],
#  ['price', 1568000.0, 0.010742232717507062],
#  ['bedrooms', 4.9, 0.015465110895031718],
#  ['bathrooms', 3.675, 0.012316525443348613],
#  ['sqft_living', 4302.2, 0.010927443626429596],
#  ['sqft_lot', 100318.68, 0.01097374635366023],
#  ['floors', 1.96, 0.02861508542853174],
#  ['waterfront', nan, 1.0],
#  ['view', 2.94, 0.014677964532110942],
#  ['condition', 3.92, 0.07876093901930824],
#  ['grade', 9.8, 0.023197666342547576],
#  ['sqft_above', 3851.4, 0.011344168171505301],
#  ['sqft_basement', 1401.4, 0.010881140899198963],
#  ['yr_built', 1933.54, 0.5102560540815854],
#  ['yr_renovated', 0.0, 0.0],
#  ['zipcode', 0.0, 0.0],
#  ['lat', 0.0, 0.0],
#  ['long', 0.0, 0.0],
#  ['sqft_living15', 3655.4, 0.01180719544381164],
#  ['sqft_lot15', 77747.81, 0.010232902717970088],
#  ['yr_renovated_korg', 0.0, 0.032458211788674356],
#  ['id_kdup', 0.0, 0.0]]

# %%
def remove_outliers(df):
    df_clone = df.copy()
    cuts = []
    do_work = '0'
    do_cut = '0'
    read_cut = '0'
    
    for col in df_clone.columns:
        print('\n')
        print('***************************************************************************')
        print(f'{col} (data type: {df_clone[col].dtype}):')
        print(f'>>>>>> remaining data size {df_clone.shape[0]} wrt {df.shape[0]}')
        print(f'>>>>>> Percent remained (previous cuts applied): {round(df_clone.shape[0]/df.shape[0],3)}')
        do_work = input('wanna continue? enter 1 (\'True\') or 0 (\'False\')')
        if do_work == '1':    
            print ('----------------------------------------------------------------------')
            print(df_clone[col].value_counts(dropna=False,normalize=True))
            print ('----------------------------------------------------------------------')
            q75, q25 = np.percentile(df_clone[col], [75 ,25])
            iqr = q75 - q25
            minVal = q25 - (1.73 * iqr)
            maxVal = q75 + (1.73 * iqr)
            print(f'*** IQR: {iqr:.6f} ********* ') 
            print(f'*** minValue: {minVal:.6f} *** ') 
            print(f'*** maxValue: {maxVal:.6f} *** ')
            print('-----------------------------------------------------------------------')
            do_cut = input('make cut? enter 1 (\'True\') or 0 (\'False\')')
            if (maxVal == minVal) & (do_cut == '1'):
                do_cut = 0
                print('minimal and maximal values are the same. cut not recommended.')
            if do_cut == '1':
                print(f'\tcut on {col} applied ... ')   
                try:
                    orig_tot = df.shape[0]
                    df_cut = df_clone.copy()
                    df_cut = df_clone[(df_clone[col]<minVal) | (df_clone[col]>maxVal)]
                    df_clone = df_clone[(df_clone[col]>minVal) & (df_clone[col]<maxVal)]
                    print(f'\tPercent removed: {round(df_cut.shape[0]/orig_tot,3)}')
                    cuts.append([col,round(minVal,6),round(maxVal,6),round(df_clone.shape[0]/df.shape[0],3),round(df_cut.shape[0]/orig_tot,3)])
                except Exception as e:
                    print('\t\t>>> Sorry! ',e)
            else:
                print(f'\tskip {col} ... ')
                read_cut = input('\tbut... wanna read cut? enter 1 (\'True\') or 0 (\'False\')')
                if read_cut == '1':
                    try:
                        orig_tot = df_clone.shape[0]
                        df_cut = df_clone.copy()
                        df_cut = df_clone[(df_clone[col]<minVal) | (df_clone[col]>maxVal)]
                        df_clone = df_clone[(df_clone[col]>minVal) & (df_clone[col]<maxVal)]
                        print(f'\tPercent removed: {round(df_cut.shape[0]/orig_tot,3)}')
                        cuts.append([col,round(minVal,6),round(maxVal,6),round(df_clone.shape[0]/df.shape[0],3),round(df_cut.shape[0]/orig_tot,3)])
                    except Exception as e:
                        print('\t\t>>> Sorry! ',e)
                    df_clone = df.copy()
                else:
                    cuts.append([col,0.,0.,0.,0.])
        else:
            cuts.append([col,0.,0.,0.,0.])
            continue
        input("Press Enter to continue...")
    return cuts, df_clone

# %%
results, kc11 = remove_outliers(kc10)
print(kc11.columns)
results
# Out:
# ***************************************************************************
# id (data type: float64):
# >>>>>> remaining data size 21597 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 1.0
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# date (data type: datetime64[ns]):
# >>>>>> remaining data size 21597 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 1.0
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# price (data type: float64):
# >>>>>> remaining data size 21597 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 1.0
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 350000.0    0.007964
# 450000.0    0.007964
# 550000.0    0.007362
# 500000.0    0.007038
# 425000.0    0.006945
#               ...
# 870515.0    0.000046
# 336950.0    0.000046
# 386100.0    0.000046
# 176250.0    0.000046
# 884744.0    0.000046
# Name: price, Length: 3622, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 323000.000000 *********
# *** minValue: -236790.000000 ***
# *** maxValue: 1203790.000000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on price applied ...
# 	Percent removed: 0.045
# Press Enter to continue...
#
#
# ***************************************************************************
# bedrooms (data type: int64):
# >>>>>> remaining data size 20619 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.955
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 3     0.467433
# 4     0.310054
# 2     0.132887
# 5     0.066347
# 6     0.011446
# 1     0.009457
# 7     0.001503
# 8     0.000436
# 9     0.000194
# 10    0.000145
# 11    0.000048
# 33    0.000048
# Name: bedrooms, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 1.000000 *********
# *** minValue: 1.270000 ***
# *** maxValue: 5.730000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on bedrooms applied ...
# 	Percent removed: 0.022
# Press Enter to continue...
#
#
# ***************************************************************************
# bathrooms (data type: float64):
# >>>>>> remaining data size 20139 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.932
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 2.50    0.258454
# 1.00    0.183922
# 1.75    0.149213
# 2.25    0.097026
# 2.00    0.093550
# 1.50    0.070361
# 2.75    0.054124
# 3.00    0.031183
# 3.50    0.027410
# 3.25    0.021451
# 3.75    0.003873
# 4.00    0.003228
# 0.75    0.002185
# 4.50    0.001589
# 4.25    0.001440
# 1.25    0.000298
# 5.00    0.000199
# 4.75    0.000199
# 0.50    0.000149
# 6.00    0.000050
# 5.25    0.000050
# 5.50    0.000050
# Name: bathrooms, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 1.000000 *********
# *** minValue: -0.230000 ***
# *** maxValue: 4.230000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on bathrooms applied ...
# 	Percent removed: 0.003
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_living (data type: int64):
# >>>>>> remaining data size 20067 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.929
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 1300    0.006877
# 1400    0.006727
# 1440    0.006578
# 1800    0.006428
# 1660    0.006379
#           ...
# 1861    0.000050
# 1451    0.000050
# 1909    0.000050
# 2005    0.000050
# 2031    0.000050
# Name: sqft_living, Length: 863, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 1020.000000 *********
# *** minValue: -354.600000 ***
# *** maxValue: 4194.600000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on sqft_living applied ...
# 	Percent removed: 0.008
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_lot (data type: int64):
# >>>>>> remaining data size 19897 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.921
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 5000     0.016334
# 6000     0.013520
# 4000     0.011811
# 7200     0.010203
# 4800     0.005428
#            ...
# 52062    0.000050
# 22326    0.000050
# 7012     0.000050
# 871      0.000050
# 36862    0.000050
# Name: sqft_lot, Length: 9078, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 5240.000000 *********
# *** minValue: -4065.200000 ***
# *** maxValue: 19305.200000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on sqft_lot applied ...
# 	Percent removed: 0.091
# Press Enter to continue...
#
#
# ***************************************************************************
# floors (data type: float64):
# >>>>>> remaining data size 17921 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.83
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 1.0    0.514034
# 2.0    0.360862
# 1.5    0.088221
# 3.0    0.031416
# 2.5    0.005134
# 3.5    0.000335
# Name: floors, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 1.000000 *********
# *** minValue: -0.730000 ***
# *** maxValue: 3.730000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on floors applied ...
# 	Percent removed: 0.0
# Press Enter to continue...
#
#
# ***************************************************************************
# waterfront (data type: float64):
# >>>>>> remaining data size 17921 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.83
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.0    0.99827
# 1.0    0.00173
# Name: waterfront, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 0.000000 *********
# *** minValue: 0.000000 ***
# *** maxValue: 0.000000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# f minimal and maximal values are the same. cut not recommended.
# 	skip waterfront ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')0
# Press Enter to continue...
#
#
# ***************************************************************************
# view (data type: float64):
# >>>>>> remaining data size 17921 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.83
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.0    0.928966
# 2.0    0.037052
# 3.0    0.014173
# 1.0    0.013727
# 4.0    0.006082
# Name: view, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 0.000000 *********
# *** minValue: 0.000000 ***
# *** maxValue: 0.000000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# f minimal and maximal values are the same. cut not recommended.
# 	skip view ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')0
# Press Enter to continue...
#
#
# ***************************************************************************
# condition (data type: int64):
# >>>>>> remaining data size 17921 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.83
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 3    0.651917
# 4    0.260923
# 5    0.079460
# 2    0.006752
# 1    0.000949
# Name: condition, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 1.000000 *********
# *** minValue: 1.270000 ***
# *** maxValue: 5.730000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on condition applied ...
# 	Percent removed: 0.001
# Press Enter to continue...
#
#
# ***************************************************************************
# grade (data type: int64):
# >>>>>> remaining data size 17904 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.829
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 7     0.460065
# 8     0.292951
# 9     0.104278
# 6     0.100648
# 10    0.028485
# 5     0.009048
# 11    0.003966
# 4     0.000559
# Name: grade, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 1.000000 *********
# *** minValue: 5.270000 ***
# *** maxValue: 9.730000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on grade applied ...
# 	Percent removed: 0.035
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_above (data type: int64):
# >>>>>> remaining data size 17151 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.794
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 1010    0.011428
# 1300    0.011370
# 1200    0.011136
# 1220    0.010262
# 1060    0.009795
#           ...
# 1352    0.000058
# 1528    0.000058
# 1544    0.000058
# 1752    0.000058
# 2145    0.000058
# Name: sqft_above, Length: 698, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 780.000000 *********
# *** minValue: -199.400000 ***
# *** maxValue: 3279.400000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on sqft_above applied ...
# 	Percent removed: 0.011
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_basement (data type: float64):
# >>>>>> remaining data size 16909 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.783
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.000000       0.590987
# 291.851724     0.021054
# 500.000000     0.011237
# 600.000000     0.010704
# 700.000000     0.010527
#                  ...
# 65.000000      0.000059
# 516.000000     0.000059
# 861.000000     0.000059
# 266.000000     0.000059
# 1710.000000    0.000059
# Name: sqft_basement, Length: 225, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 500.000000 *********
# *** minValue: -865.000000 ***
# *** maxValue: 1365.000000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on sqft_basement applied ...
# 	Percent removed: 0.009
# Press Enter to continue...
#
#
# ***************************************************************************
# yr_built (data type: int64):
# >>>>>> remaining data size 16713 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.774
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 2014    0.024951
# 2005    0.021361
# 2003    0.020762
# 2004    0.020044
# 2006    0.019685
#           ...
# 1902    0.001436
# 1932    0.001197
# 1934    0.000778
# 1935    0.000778
# 1933    0.000718
# Name: yr_built, Length: 116, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 46.000000 *********
# *** minValue: 1870.420000 ***
# *** maxValue: 2075.580000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')0
# 	skip yr_built ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')0
# Press Enter to continue...
#
#
# ***************************************************************************
# yr_renovated (data type: float64):
# >>>>>> remaining data size 16713 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.774
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.0    0.970442
# 1.0    0.029558
# Name: yr_renovated, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 0.000000 *********
# *** minValue: 0.000000 ***
# *** maxValue: 0.000000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# f minimal and maximal values are the same. cut not recommended.
# 	skip yr_renovated ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')0
# Press Enter to continue...
#
#
# ***************************************************************************
# zipcode (data type: int64):
# >>>>>> remaining data size 16713 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.774
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# lat (data type: float64):
# >>>>>> remaining data size 16713 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.774
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# long (data type: float64):
# >>>>>> remaining data size 16713 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.774
# wanna continue? enter 1 ('True') or 0 ('False')0
#
#
# ***************************************************************************
# sqft_living15 (data type: int64):
# >>>>>> remaining data size 16713 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.774
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 1540    0.010950
# 1440    0.010351
# 1500    0.010052
# 1560    0.009992
# 1510    0.009633
#           ...
# 4410    0.000060
# 2409    0.000060
# 2425    0.000060
# 2697    0.000060
# 2049    0.000060
# Name: sqft_living15, Length: 586, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 680.000000 *********
# *** minValue: 263.600000 ***
# *** maxValue: 3296.400000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on sqft_living15 applied ...
# 	Percent removed: 0.005
# Press Enter to continue...
#
#
# ***************************************************************************
# sqft_lot15 (data type: int64):
# >>>>>> remaining data size 16613 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.769
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 5000     0.022031
# 4000     0.019563
# 6000     0.015048
# 7200     0.010895
# 7500     0.007765
#            ...
# 4427     0.000060
# 8509     0.000060
# 10556    0.000060
# 8493     0.000060
# 6147     0.000060
# Name: sqft_lot15, Length: 6237, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 4000.000000 *********
# *** minValue: -2120.000000 ***
# *** maxValue: 15720.000000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# 	cut on sqft_lot15 applied ...
# 	Percent removed: 0.014
# Press Enter to continue...
#
#
# ***************************************************************************
# yr_renovated_korg (data type: float64):
# >>>>>> remaining data size 16319 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.756
# wanna continue? enter 1 ('True') or 0 ('False')1
# ----------------------------------------------------------------------
# 0.0       0.971077
# 2014.0    0.003493
# 2013.0    0.001471
# 2000.0    0.001164
# 2003.0    0.001103
#             ...
# 1934.0    0.000061
# 1951.0    0.000061
# 1962.0    0.000061
# 1946.0    0.000061
# 1976.0    0.000061
# Name: yr_renovated_korg, Length: 67, dtype: float64
# ----------------------------------------------------------------------
# *** IQR: 0.000000 *********
# *** minValue: 0.000000 ***
# *** maxValue: 0.000000 ***
# -----------------------------------------------------------------------
# make cut? enter 1 ('True') or 0 ('False')1
# f minimal and maximal values are the same. cut not recommended.
# 	skip yr_renovated_korg ...
# 	but... wanna read cut? enter 1 ('True') or 0 ('False')0
# Press Enter to continue...
#
#
# ***************************************************************************
# id_kdup (data type: int64):
# >>>>>> remaining data size 16319 wrt 21597
# >>>>>> Percent remained (previous cuts applied): 0.756
# wanna continue? enter 1 ('True') or 0 ('False')0
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'yr_renovated_korg',
#        'id_kdup'],
#       dtype='object')
# [['id', 0.0, 0.0, 0.0, 0.0],
#  ['date', 0.0, 0.0, 0.0, 0.0],
#  ['price', -236790.0, 1203790.0, 0.955, 0.045],
#  ['bedrooms', 1.27, 5.73, 0.932, 0.022],
#  ['bathrooms', -0.23, 4.23, 0.929, 0.003],
#  ['sqft_living', -354.6, 4194.6, 0.921, 0.008],
#  ['sqft_lot', -4065.2, 19305.2, 0.83, 0.091],
#  ['floors', -0.73, 3.73, 0.83, 0.0],
#  ['waterfront', 0.0, 0.0, 0.0, 0.0],
#  ['view', 0.0, 0.0, 0.0, 0.0],
#  ['condition', 1.27, 5.73, 0.829, 0.001],
#  ['grade', 5.27, 9.73, 0.794, 0.035],
#  ['sqft_above', -199.4, 3279.4, 0.783, 0.011],
#  ['sqft_basement', -865.0, 1365.0, 0.774, 0.009],
#  ['yr_built', 0.0, 0.0, 0.0, 0.0],
#  ['yr_renovated', 0.0, 0.0, 0.0, 0.0],
#  ['zipcode', 0.0, 0.0, 0.0, 0.0],
#  ['lat', 0.0, 0.0, 0.0, 0.0],
#  ['long', 0.0, 0.0, 0.0, 0.0],
#  ['sqft_living15', 263.6, 3296.4, 0.769, 0.005],
#  ['sqft_lot15', -2120.0, 15720.0, 0.756, 0.014],
#  ['yr_renovated_korg', 0.0, 0.0, 0.0, 0.0],
#  ['id_kdup', 0.0, 0.0, 0.0, 0.0]]

# %% [markdown]
# # exploring data

# %% [markdown]
# ## count unique values

# %%
def unique_features_plt(df):
    df_clone = df.copy()
    df_clone = df_clone.loc[:, df_clone.dtypes != 'object']
    print(df_clone.columns)
    print(df_clone.nunique())
    
    fig, ax = plt.subplots(1,1,figsize = (15, 5)) 
    plt.bar(df_clone.columns,df_clone.nunique(),color='green',alpha=0.4,width=0.2)
    plt.xticks(rotation=90)
    plt.yscale('log')
    plt.show()
    
    return None

# %%
unique_features_plt(kc11)
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'yr_renovated_korg',
#        'id_kdup'],
#       dtype='object')
# id                   16181
# date                   369
# price                 2976
# bedrooms                 4
# bathrooms               15
# sqft_living            659
# sqft_lot              6813
# floors                   6
# waterfront               2
# view                     5
# condition                4
# grade                    4
# sqft_above             599
# sqft_basement          170
# yr_built               116
# yr_renovated             2
# zipcode                 70
# lat                   4689
# long                   605
# sqft_living15          531
# sqft_lot15            5979
# yr_renovated_korg       67
# id_kdup              16181
# dtype: int64

# %% [markdown]
# ## understand data

# %%
kc11.hist(figsize=(30,20))
plt.show()

# %% [markdown]
# ##  inspect features
#
# Column Names and descriptions for Kings County Data Set
# * **id** - unique identified for a house
# * **dateDate** - house was sold
# * **pricePrice** -  is prediction target
# * **bedroomsNumber** -  of Bedrooms/House
# * **bathroomsNumber** -  of bathrooms/bedrooms
# * **sqft_livingsquare** -  footage of the home
# * **sqft_lotsquare** -  footage of the lot
# * **floorsTotal** -  floors (levels) in house
# * **waterfront** - House which has a view to a waterfront
# * **view** - Has been viewed
# * **condition** - How good the condition is ( Overall )
# * **grade** - overall grade given to the housing unit, based on King County grading system
# * **sqft_above** - square footage of house apart from basement
# * **sqft_basement** - square footage of the basement
# * **yr_built** - Built Year
# * **yr_renovated** - Year when house was renovated
# * **zipcode** - zip
# * **lat** - Latitude coordinate
# * **long** - Longitude coordinate
# * **sqft_living15** - The square footage of interior housing living space for the nearest 15 neighbors
# * **sqft_lot15** - The square footage of the land lots for the nearest 15 neighbors

# %% [markdown]
# ### continuous features

# %%
selcols = list(col for col in kc11.columns if (col != 'id') & (col != 'date'))
kc12 = kc11.loc[:, selcols]
kc13_cont = kc12.loc[:, (kc12.dtypes != 'object') & (kc12.nunique() > 20)]
print(kc13_cont.shape)
kc13_cont.head()
# Out:
# (16319, 13)
#       price  sqft_living  sqft_lot  sqft_above  sqft_basement  yr_built  \
# 0  221900.0         1180      5650        1180            0.0      1955
# 1  538000.0         2570      7242        2170          400.0      1951
# 2  180000.0          770     10000         770            0.0      1933
# 3  604000.0         1960      5000        1050          910.0      1965
# 4  510000.0         1680      8080        1680            0.0      1987
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  yr_renovated_korg  \
# 0    98178  47.5112 -122.257           1340        5650                0.0
# 1    98125  47.7210 -122.319           1690        7639             1991.0
# 2    98028  47.7379 -122.233           2720        8062                0.0
# 3    98136  47.5208 -122.393           1360        5000                0.0
# 4    98074  47.6168 -122.045           1800        7503                0.0
#
#       id_kdup
# 0  7129300520
# 1  6414100192
# 2  5631500400
# 3  2487200875
# 4  1954400510

# %%
fig, axes = plt.subplots(nrows=kc13_cont.shape[1] // 4, ncols=4, figsize=(20,10))
continuous = list(col for col in kc13_cont.columns)
for xcol, ax in zip(continuous, axes.flatten()):
    print(xcol,ax)
    ax.hist(kc12_cont[xcol], bins='auto', alpha=0.4, color='green')
    ax.set_title(xcol)
    ax.set_yscale('log')
    
fig.tight_layout()
# Out:
# price AxesSubplot(0.125,0.657941;0.168478x0.222059)
# sqft_living AxesSubplot(0.327174,0.657941;0.168478x0.222059)
# sqft_lot AxesSubplot(0.529348,0.657941;0.168478x0.222059)
# sqft_above AxesSubplot(0.731522,0.657941;0.168478x0.222059)
# sqft_basement AxesSubplot(0.125,0.391471;0.168478x0.222059)
# yr_built AxesSubplot(0.327174,0.391471;0.168478x0.222059)
# zipcode AxesSubplot(0.529348,0.391471;0.168478x0.222059)
# lat AxesSubplot(0.731522,0.391471;0.168478x0.222059)
# long AxesSubplot(0.125,0.125;0.168478x0.222059)
# sqft_living15 AxesSubplot(0.327174,0.125;0.168478x0.222059)
# sqft_lot15 AxesSubplot(0.529348,0.125;0.168478x0.222059)
# yr_renovated_korg AxesSubplot(0.731522,0.125;0.168478x0.222059)

# %%
cont_cols = ['price','sqft_living','sqft_lot','sqft_above','sqft_basement','sqft_living15','sqft_lot15',
             'yr_built','zipcode']
kc14_cont = kc13_cont.loc[:,cont_cols]
kc14_cont['sqft_tot'] = kc14_cont['sqft_above'] + kc14_cont['sqft_basement']
kc14_cont = kc14_cont.drop(['sqft_above','sqft_basement'],axis=1)
print(kc14_cont.shape)
kc14_cont.head()
# Out:
# (16319, 6)
#       price  sqft_living  sqft_lot  sqft_living15  sqft_lot15  sqft_tot
# 0  221900.0         1180      5650           1340        5650    1180.0
# 1  538000.0         2570      7242           1690        7639    2570.0
# 2  180000.0          770     10000           2720        8062     770.0
# 3  604000.0         1960      5000           1360        5000    1960.0
# 4  510000.0         1680      8080           1800        7503    1680.0

# %%
kc14_cont.plot(kind='scatter',x='sqft_tot',y='sqft_living',c='g',alpha=0.4)

# %%
kc14_cont = kc14_cont.drop(['sqft_tot'],axis=1)
print(kc14_cont.shape)
kc14_cont.head()
# Out:
# (16319, 5)
#       price  sqft_living  sqft_lot  sqft_living15  sqft_lot15
# 0  221900.0         1180      5650           1340        5650
# 1  538000.0         2570      7242           1690        7639
# 2  180000.0          770     10000           2720        8062
# 3  604000.0         1960      5000           1360        5000
# 4  510000.0         1680      8080           1800        7503

# %% [markdown]
# ### categoricals features

# %% [markdown]
# ## check linearity

# %%
# Your code here 
sm = pd.plotting.scatter_matrix(kc14_cont, color='green', alpha=0.2, figsize=[15, 15]);

# Rotates the text
[s.xaxis.label.set_rotation(0) for s in sm.reshape(-1)]
[s.yaxis.label.set_rotation(0) for s in sm.reshape(-1)]

# May need to offset label when rotating to prevent overlap of figure
[s.get_yaxis().set_label_coords(-0.3,0.5) for s in sm.reshape(-1)]

# Hide all ticks
[s.set_xticks(()) for s in sm.reshape(-1)]
[s.set_yticks(()) for s in sm.reshape(-1)]

plt.show()

# %%
kc14_cont.corr()
# Out:
#                   price  sqft_living  sqft_lot  sqft_living15  sqft_lot15
# price          1.000000     0.512244 -0.089257       0.434334   -0.100993
# sqft_living    0.512244     1.000000  0.166807       0.694065    0.149108
# sqft_lot      -0.089257     0.166807  1.000000       0.212731    0.875662
# sqft_living15  0.434334     0.694065  0.212731       1.000000    0.231834
# sqft_lot15    -0.100993     0.149108  0.875662       0.231834    1.000000

# %%
cc_df = kc14_cont.corr().abs().stack().reset_index().sort_values(0, ascending=True)
print(cc_df.head())
cc_df['pairs'] = list(zip(cc_df.level_0, cc_df.level_1))
ccpairs_df = cc_df.set_index('pairs')
ccpairs_df.columns = ['cc']
ccpairs_df = ccpairs_df.drop_duplicates()
ccpairs_df.head()

# %% [markdown]
# ## build baseline model

# %% [markdown]
# ## check normality

# %% [markdown]
# ## check  homoscedasticity

# %% [markdown]
# ## investigate multicollinearity

# %% [markdown]
# # EDA Q1:

# %% [markdown]
# # EDA Q2:

# %% [markdown]
# # modeling data

# %% [markdown]
# ## remove uninfluential features
